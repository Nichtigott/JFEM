# %%
push!(LOAD_PATH,"/home/nichtigott/FEM/jfem/.")
# Out:
# 4-element Vector{String}:
#  "@"
#  "@v#.#"
#  "@stdlib"
#  "/home/nichtigott/FEM/jfem/."

# %%
import Gausslegendre1D
import Gausslegendre2D
import Gausslegendre3D
import Plots

# %%
a=Gausslegendre1D.creatgp(8)
b=Gausslegendre2D.creatgpquad(a)
c=Gausslegendre3D.creatgpHEX(a)
# Out:
# 512×4 Matrix{Float64}:
#  0.00103731  -0.96029  -0.96029   -0.96029
#  0.00227879  -0.96029  -0.96029   -0.796666
#  0.00321462  -0.96029  -0.96029   -0.525532
#  0.0037165   -0.96029  -0.96029   -0.183435
#  0.0037165   -0.96029  -0.96029    0.183435
#  0.00321462  -0.96029  -0.96029    0.525532
#  0.00227879  -0.96029  -0.96029    0.796666
#  0.00103731  -0.96029  -0.96029    0.96029
#  0.00227879  -0.96029  -0.796666  -0.96029
#  0.00500609  -0.96029  -0.796666  -0.796666
#  ⋮
#  0.00227879   0.96029   0.796666   0.96029
#  0.00103731   0.96029   0.96029   -0.96029
#  0.00227879   0.96029   0.96029   -0.796666
#  0.00321462   0.96029   0.96029   -0.525532
#  0.0037165    0.96029   0.96029   -0.183435
#  0.0037165    0.96029   0.96029    0.183435
#  0.00321462   0.96029   0.96029    0.525532
#  0.00227879   0.96029   0.96029    0.796666
#  0.00103731   0.96029   0.96029    0.96029

# %%
a=Gausslegendre1D.creatgp(8)
Gausslegendre1D.draw(a)
b=Gausslegendre3D.creatgpHEX(a)
Gausslegendre3D.draw(b)
# Out:
# 512
